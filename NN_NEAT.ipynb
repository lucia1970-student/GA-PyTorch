# %% [markdown]
# <a href="https://colab.research.google.com/github/lucia1970-student/GA-PyTorch/blob/main/NN_NEAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/cours_python/FSCI2610/projet
# Out:
# /content/drive/MyDrive/Colab Notebooks/cours_python/FSCI2610/projet

# %%
# !pip install neat_python
# Out:
# Requirement already satisfied: neat_python in /usr/local/lib/python3.11/dist-packages (0.92)

# %%
import neat
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix

# Load dataset
df = pd.read_csv("voice_data.csv")

# Filter data to include only 'ASD' and 'CTRL' groups (where CTRL is the combination of 'IC' and 'SLI')
df_filtered = df[(df['Group'] == 'ASD') | (df['Group'] == 'IC') | (df['Group'] == 'SLI')].copy()

# Create a new target variable 'y' with binary labels:
# 0 for 'CTRL' (combined 'IC' and 'SLI') and 1 for 'ASD'
df_filtered['Group_Encoded'] = np.where(df_filtered['Group'] == 'ASD', 1, 0)  # 1 for ASD, 0 for CTRL

y = df_filtered['Group_Encoded'].values
X = df_filtered.iloc[:, 1:-1].values  # Features

# Normalize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split dataset into train & test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

le = LabelBinarizer()
y_train = le.fit_transform(y_train) # Fit and transform training labels
y_test = le.transform(y_test) # Transform test labels

# Define the fitness function for NEAT
def evaluate_genome(genomes, config):
    """Evaluate a list of genomes using ROC AUC for binary classification."""
    for genome_id, genome in genomes:
        net = neat.nn.FeedForwardNetwork.create(genome, config)

        # Predict on training set (get continuous predictions)
        predictions = []
        for i in range(len(X_train)):
            output = net.activate(X_train[i])
            predictions.append(output[0])  # Use raw output as continuous prediction

        # Reshape predictions to a 2D array with a single column or 1D array
        predictions = np.array(predictions).reshape(-1, 1)

        # Compute ROC AUC and assign fitness
        auc_score = roc_auc_score(y_train, predictions) # Remove multi_class for binary
        genome.fitness = auc_score  # Fitness = ROC AUC score

# NEAT Configuration
def run_neat():
    """Runs NEAT to evolve a neural network for classification."""
    config_path = "neat_config.txt"  # Make sure you have this config file
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation, config_path)

    # Modify reproduction config to create a new species when extinction occurs
    config.reproduction_config.species_elitism = 0  # Allow extinction
    config.reproduction_config.elitism = 0  # Allow extinction of best individual
    config.reproduction_config.min_species_size = 2  # Minimum species size to avoid extinction

    # Increase population size to promote diversity
    config.pop_size = 200  # Increased from default (usually 150)

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))

    # Run NEAT evolution for 50 generations
    winner = population.run(evaluate_genome, n=50)

    # Print best genome
    print("Best genome:", winner)

    # Evaluate the best network on test data
    best_net = neat.nn.FeedForwardNetwork.create(winner, config)

    # Get continuous predictions and reshape to 2D or 1D
    predictions = [best_net.activate(x)[0] for x in X_test]
    predictions = np.array(predictions).reshape(-1, 1) # Reshape to 2D

    test_auc = roc_auc_score(y_test, predictions)
    print(f"Final test ROC AUC: {test_auc:.4f}")

    return predictions

# Run NEAT evolution
predictions = run_neat()

# Apply threshold to get binary predictions
predictions_binary = (predictions >= 0.5).astype(int).ravel()

# Calculate and print classification metrics
print("\nClassification report: \n")
print(classification_report(y_test, predictions_binary))

cm = confusion_matrix(y_test, predictions_binary)
print("\nConfusion Matrix: \n")
print(cm)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.53028 stdev: 0.10691
# Best fitness: 0.80048 - size: (1, 19) - species 1 - id 154
# Average adjusted fitness: 0.205
# Mean genetic distance 1.086, standard deviation 0.437
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   200      0.5    0.205     0
# Total extinctions: 0
# Generation time: 0.423 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.61853 stdev: 0.10697
# Best fitness: 0.83594 - size: (1, 19) - species 1 - id 207
# Average adjusted fitness: 0.240
# Mean genetic distance 1.263, standard deviation 0.409
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   200      0.6    0.240     0
# Total extinctions: 0
# Generation time: 0.440 sec (0.431 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 0.68277 stdev: 0.10925
# Best fitness: 0.87981 - size: (1, 19) - species 1 - id 588
# Average adjusted fitness: 0.344
# Mean genetic distance 1.359, standard deviation 0.387
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   200      0.7    0.344     0
# Total extinctions: 0
# Generation time: 0.448 sec (0.437 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 0.73352 stdev: 0.10804
# Best fitness: 0.88822 - size: (3, 20) - species 1 - id 628
# Average adjusted fitness: 0.380
# Mean genetic distance 1.513, standard deviation 0.377
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   200      0.7    0.380     0
# Total extinctions: 0
# Generation time: 0.466 sec (0.444 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 0.78540 stdev: 0.09645
# Best fitness: 0.90144 - size: (3, 20) - species 1 - id 909
# Average adjusted fitness: 0.303
# Mean genetic distance 1.541, standard deviation 0.415
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   200      0.8    0.303     0
# Total extinctions: 0
# Generation time: 0.425 sec (0.440 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 0.81533 stdev: 0.08935
# Best fitness: 0.90745 - size: (1, 16) - species 1 - id 1060
# Average adjusted fitness: 0.327
# Mean genetic distance 1.382, standard deviation 0.387
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   200      0.8    0.327     0
# Total extinctions: 0
# Generation time: 0.460 sec (0.444 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 0.82590 stdev: 0.07669
# Best fitness: 0.91526 - size: (1, 13) - species 1 - id 1366
# Average adjusted fitness: 0.326
# Mean genetic distance 1.449, standard deviation 0.392
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   200      0.8    0.326     0
# Total extinctions: 0
# Generation time: 0.459 sec (0.446 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 0.82426 stdev: 0.09399
# Best fitness: 0.91947 - size: (1, 13) - species 1 - id 1498
# Average adjusted fitness: 0.428
# Mean genetic distance 1.595, standard deviation 0.399
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   200      0.8    0.428     1
# Total extinctions: 0
# Generation time: 0.414 sec (0.442 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 0.82367 stdev: 0.10471
# Best fitness: 0.93329 - size: (2, 16) - species 1 - id 1700
# Average adjusted fitness: 0.356
# Mean genetic distance 1.590, standard deviation 0.419
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   200      0.8    0.356     2
# Total extinctions: 0
# Generation time: 0.450 sec (0.443 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 0.83305 stdev: 0.10761
# Best fitness: 0.93389 - size: (2, 13) - species 1 - id 1982
# Average adjusted fitness: 0.427
# Mean genetic distance 2.278, standard deviation 0.911
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   150      0.8    0.427     0
#      2    0     5       --       --     0
#      3    0    45       --       --     0
# Total extinctions: 0
# Generation time: 0.426 sec (0.441 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 0.84285 stdev: 0.10652
# Best fitness: 0.93750 - size: (1, 12) - species 2 - id 2062
# Average adjusted fitness: 0.424
# Mean genetic distance 2.447, standard deviation 1.058
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    96      0.8    0.425     0
#      2    1    34      0.8    0.425     0
#      3    1    70      0.8    0.422     0
# Total extinctions: 0
# Generation time: 0.448 sec (0.444 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 0.83938 stdev: 0.13002
# Best fitness: 0.93510 - size: (1, 11) - species 2 - id 2261
# Average adjusted fitness: 0.414
# Mean genetic distance 2.573, standard deviation 1.254
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    99      0.8    0.409     1
#      2    2    47      0.9    0.436     0
#      3    2    54      0.8    0.396     1
# Total extinctions: 0
# Generation time: 0.439 sec (0.443 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 0.84734 stdev: 0.12481
# Best fitness: 0.93990 - size: (1, 11) - species 2 - id 2552
# Average adjusted fitness: 0.486
# Mean genetic distance 2.593, standard deviation 1.244
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    91      0.8    0.477     2
#      2    3    50      0.9    0.504     0
#      3    3    59      0.8    0.476     0
# Total extinctions: 0
# Generation time: 0.444 sec (0.443 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 0.83130 stdev: 0.14342
# Best fitness: 0.93930 - size: (3, 16) - species 3 - id 2695
# Average adjusted fitness: 0.450
# Mean genetic distance 2.488, standard deviation 1.080
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    78      0.8    0.468     0
#      2    4    59      0.8    0.459     1
#      3    4    63      0.8    0.423     1
# Total extinctions: 0
# Generation time: 0.466 sec (0.443 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 0.87376 stdev: 0.10824
# Best fitness: 0.94291 - size: (3, 16) - species 1 - id 2927
# Average adjusted fitness: 0.451
# Mean genetic distance 2.447, standard deviation 0.856
# Population of 201 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    80      0.9    0.454     0
#      2    5    57      0.9    0.461     0
#      3    5    64      0.9    0.438     0
# Total extinctions: 0
# Generation time: 0.450 sec (0.446 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 0.86026 stdev: 0.13029
# Best fitness: 0.94351 - size: (3, 15) - species 1 - id 3122
# Average adjusted fitness: 0.372
# Mean genetic distance 2.407, standard deviation 0.785
# Population of 201 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    80      0.8    0.347     1
#      2    6    57      0.9    0.411     0
#      3    6    64      0.8    0.358     1
# Total extinctions: 0
# Generation time: 0.465 sec (0.446 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 0.86387 stdev: 0.11968
# Best fitness: 0.94411 - size: (4, 18) - species 1 - id 3230
# Average adjusted fitness: 0.383
# Mean genetic distance 2.345, standard deviation 0.686
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    94      0.9    0.396     2
#      2    7    47      0.9    0.397     1
#      3    7    59      0.8    0.356     2
# Total extinctions: 0
# Generation time: 0.433 sec (0.444 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 0.85312 stdev: 0.14033
# Best fitness: 0.94651 - size: (3, 14) - species 1 - id 3519
# Average adjusted fitness: 0.424
# Mean genetic distance 2.458, standard deviation 0.695
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    99      0.9    0.419     3
#      2    8    46      0.9    0.444     2
#      3    8    55      0.8    0.408     3
# Total extinctions: 0
# Generation time: 0.818 sec (0.484 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 0.87240 stdev: 0.12356
# Best fitness: 0.94772 - size: (4, 13) - species 1 - id 3699
# Average adjusted fitness: 0.380
# Mean genetic distance 2.491, standard deviation 0.747
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    78      0.9    0.392     0
#      2    9    73      0.9    0.385     3
#      3    9    49      0.9    0.362     4
# Total extinctions: 0
# Generation time: 0.722 sec (0.511 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 0.86889 stdev: 0.12850
# Best fitness: 0.94832 - size: (4, 12) - species 1 - id 3945
# Average adjusted fitness: 0.442
# Mean genetic distance 2.339, standard deviation 0.632
# Population of 201 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   102      0.9    0.448     1
#      2   10    64      0.9    0.465     4
#      3   10    35      0.8    0.414     5
# Total extinctions: 0
# Generation time: 0.682 sec (0.537 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 0.84814 stdev: 0.15092
# Best fitness: 0.94892 - size: (4, 21) - species 1 - id 4100
# Average adjusted fitness: 0.422
# Mean genetic distance 2.235, standard deviation 0.505
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20   116      0.9    0.436     2
#      2   11    32      0.8    0.420     5
#      3   11    52      0.8    0.410     6
# Total extinctions: 0
# Generation time: 0.723 sec (0.564 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 0.85843 stdev: 0.14032
# Best fitness: 0.95673 - size: (5, 16) - species 1 - id 4335
# Average adjusted fitness: 0.455
# Mean genetic distance 2.194, standard deviation 0.466
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    42      0.9    0.486     3
#      2   12    49      0.8    0.440     6
#      3   12   109      0.8    0.440     7
# Total extinctions: 0
# Generation time: 0.708 sec (0.591 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 0.81805 stdev: 0.17492
# Best fitness: 0.94712 - size: (4, 12) - species 3 - id 4544
# Average adjusted fitness: 0.422
# Mean genetic distance 2.158, standard deviation 0.413
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22   107      0.7    0.335     4
#      2   13    51      0.8    0.459     7
#      3   13    42      0.8    0.471     8
# Total extinctions: 0
# Generation time: 0.745 sec (0.621 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 0.83989 stdev: 0.16226
# Best fitness: 0.94411 - size: (4, 14) - species 1 - id 4760
# Average adjusted fitness: 0.443
# Mean genetic distance 2.182, standard deviation 0.541
# Population of 201 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23   107      0.8    0.426     5
#      2   14    48      0.9    0.466     8
#      3   14    46      0.8    0.436     9
# Total extinctions: 0
# Generation time: 0.633 sec (0.638 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 0.85214 stdev: 0.15084
# Best fitness: 0.94772 - size: (5, 16) - species 1 - id 4842
# Average adjusted fitness: 0.418
# Mean genetic distance 2.186, standard deviation 0.575
# Population of 201 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    84      0.8    0.403     6
#      2   15    44      0.9    0.446     9
#      3   15    73      0.8    0.406    10
# Total extinctions: 0
# Generation time: 0.479 sec (0.641 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 0.84780 stdev: 0.15464
# Best fitness: 0.94952 - size: (4, 16) - species 3 - id 5015
# Average adjusted fitness: 0.444
# Mean genetic distance 2.152, standard deviation 0.658
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25   109      0.8    0.427     7
#      2   16    43      0.9    0.457    10
#      3   16    48      0.9    0.449    11
# Total extinctions: 0
# Generation time: 0.424 sec (0.637 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 0.85530 stdev: 0.14679
# Best fitness: 0.95312 - size: (3, 14) - species 1 - id 5335
# Average adjusted fitness: 0.471
# Mean genetic distance 2.218, standard deviation 0.658
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26   111      0.8    0.447     8
#      2   17    28      0.9    0.464    11
#      3   17    61      0.9    0.501     0
# Total extinctions: 0
# Generation time: 0.719 sec (0.665 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 0.87729 stdev: 0.12485
# Best fitness: 0.95613 - size: (4, 13) - species 1 - id 5485
# Average adjusted fitness: 0.467
# Mean genetic distance 2.255, standard deviation 0.617
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    97      0.9    0.487     0
#      2   18    48      0.9    0.465    12
#      3   18    55      0.9    0.448     1
# Total extinctions: 0
# Generation time: 0.437 sec (0.627 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 0.85777 stdev: 0.14803
# Best fitness: 0.95192 - size: (4, 13) - species 1 - id 5749
# Average adjusted fitness: 0.438
# Mean genetic distance 2.145, standard deviation 0.547
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    64      0.8    0.418     1
#      2   19    79      0.9    0.442    13
#      3   19    57      0.9    0.454     2
# Total extinctions: 0
# Generation time: 0.436 sec (0.599 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 0.85466 stdev: 0.14742
# Best fitness: 0.95012 - size: (4, 11) - species 2 - id 5867
# Average adjusted fitness: 0.440
# Mean genetic distance 2.065, standard deviation 0.428
# Population of 201 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    40      0.8    0.426     2
#      2   20    64      0.9    0.437    14
#      3   20    97      0.9    0.455     3
# Total extinctions: 0
# Generation time: 0.421 sec (0.573 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 0.83703 stdev: 0.16167
# Best fitness: 0.95252 - size: (3, 11) - species 2 - id 6120
#
# Species 2 with 64 members is stagnated: removing it
# Average adjusted fitness: 0.404
# Mean genetic distance 2.051, standard deviation 0.353
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30   125      0.8    0.389     3
#      3   21    75      0.8    0.419     4
# Total extinctions: 0
# Generation time: 0.441 sec (0.544 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 0.84678 stdev: 0.16093
# Best fitness: 0.95373 - size: (4, 13) - species 1 - id 6237
# Average adjusted fitness: 0.461
# Mean genetic distance 2.000, standard deviation 0.346
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31   150      0.9    0.470     4
#      3   22    50      0.8    0.452     5
# Total extinctions: 0
# Generation time: 0.426 sec (0.516 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 0.85565 stdev: 0.15243
# Best fitness: 0.95312 - size: (3, 10) - species 1 - id 6477
# Average adjusted fitness: 0.404
# Mean genetic distance 2.065, standard deviation 0.465
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    53      0.9    0.431     5
#      3   23   147      0.8    0.378     6
# Total extinctions: 0
# Generation time: 0.441 sec (0.486 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 0.86116 stdev: 0.14417
# Best fitness: 0.95493 - size: (4, 11) - species 3 - id 6655
# Average adjusted fitness: 0.471
# Mean genetic distance 2.180, standard deviation 0.396
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33   163      0.8    0.453     6
#      3   24    37      0.9    0.490     7
# Total extinctions: 0
# Generation time: 0.425 sec (0.465 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 0.86788 stdev: 0.14321
# Best fitness: 0.94892 - size: (3, 11) - species 1 - id 6902
# Average adjusted fitness: 0.443
# Mean genetic distance 2.063, standard deviation 0.366
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34   129      0.9    0.454     7
#      3   25    71      0.8    0.432     8
# Total extinctions: 0
# Generation time: 0.418 sec (0.459 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 0.86384 stdev: 0.14527
# Best fitness: 0.95433 - size: (6, 18) - species 1 - id 7157
# Average adjusted fitness: 0.459
# Mean genetic distance 2.051, standard deviation 0.376
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    78      0.9    0.456     8
#      3   26   122      0.9    0.462     9
# Total extinctions: 0
# Generation time: 0.436 sec (0.460 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 0.85427 stdev: 0.14909
# Best fitness: 0.96034 - size: (6, 20) - species 1 - id 7258
# Average adjusted fitness: 0.495
# Mean genetic distance 2.046, standard deviation 0.285
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36   124      0.9    0.500     9
#      3   27    76      0.9    0.489    10
# Total extinctions: 0
# Generation time: 0.458 sec (0.434 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 0.86196 stdev: 0.13956
# Best fitness: 0.95433 - size: (5, 16) - species 1 - id 7470
# Average adjusted fitness: 0.427
# Mean genetic distance 2.033, standard deviation 0.274
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37   118      0.9    0.426    10
#      3   28    82      0.9    0.429    11
# Total extinctions: 0
# Generation time: 0.453 sec (0.436 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 0.88345 stdev: 0.11758
# Best fitness: 0.96094 - size: (4, 13) - species 3 - id 7776
# Average adjusted fitness: 0.463
# Mean genetic distance 1.995, standard deviation 0.350
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38   159      0.9    0.440    11
#      3   29    41      0.9    0.485     0
# Total extinctions: 0
# Generation time: 0.496 sec (0.442 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 0.86272 stdev: 0.14135
# Best fitness: 0.95613 - size: (6, 18) - species 3 - id 7945
# Average adjusted fitness: 0.393
# Mean genetic distance 1.941, standard deviation 0.345
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    93      0.9    0.399    12
#      3   30   107      0.9    0.387     1
# Total extinctions: 0
# Generation time: 0.494 sec (0.449 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 0.88788 stdev: 0.11500
# Best fitness: 0.95312 - size: (7, 22) - species 3 - id 8035
# Average adjusted fitness: 0.447
# Mean genetic distance 1.926, standard deviation 0.345
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40   118      0.9    0.445    13
#      3   31    82      0.9    0.450     2
# Total extinctions: 0
# Generation time: 0.475 sec (0.452 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 0.87218 stdev: 0.13175
# Best fitness: 0.96094 - size: (5, 16) - species 3 - id 8346
# Average adjusted fitness: 0.411
# Mean genetic distance 1.953, standard deviation 0.346
# Population of 200 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41   103      0.9    0.402    14
#      3   32    97      0.9    0.420     3
# Total extinctions: 0
# Generation time: 0.476 sec (0.457 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 0.87447 stdev: 0.13239
# Best fitness: 0.95913 - size: (5, 15) - species 3 - id 8533
#
# Species 1 with 103 members is stagnated: removing it
# Average adjusted fitness: 0.430
# Mean genetic distance 1.985, standard deviation 0.275
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   33   200      0.9    0.430     4
# Total extinctions: 0
# Generation time: 0.469 sec (0.460 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 0.84993 stdev: 0.15600
# Best fitness: 0.95793 - size: (8, 20) - species 3 - id 8618
# Average adjusted fitness: 0.437
# Mean genetic distance 2.283, standard deviation 0.408
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   34   124      0.8    0.437     5
#      4    0    38       --       --     0
#      5    0    38       --       --     0
# Total extinctions: 0
# Generation time: 0.485 sec (0.466 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 0.85933 stdev: 0.14745
# Best fitness: 0.96094 - size: (5, 20) - species 3 - id 8993
# Average adjusted fitness: 0.455
# Mean genetic distance 2.425, standard deviation 0.448
# Population of 200 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   35    58      0.9    0.468     6
#      4    1    58      0.8    0.445     0
#      5    1    84      0.8    0.451     0
# Total extinctions: 0
# Generation time: 0.497 sec (0.474 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 0.85589 stdev: 0.14583
# Best fitness: 0.96094 - size: (6, 20) - species 5 - id 9206
# Average adjusted fitness: 0.467
# Mean genetic distance 2.413, standard deviation 0.438
# Population of 200 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   36    37      0.8    0.454     7
#      4    2    56      0.9    0.478     0
#      5    2    89      0.9    0.470     0
#      6    0    18       --       --     0
# Total extinctions: 0
# Generation time: 0.779 sec (0.508 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 0.86473 stdev: 0.14321
# Best fitness: 0.95853 - size: (6, 20) - species 3 - id 9324
# Average adjusted fitness: 0.424
# Mean genetic distance 2.424, standard deviation 0.424
# Population of 200 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   37    14      0.8    0.409     8
#      4    3   135      0.9    0.447     0
#      5    3    26      0.9    0.428     0
#      6    1    25      0.8    0.413     0
# Total extinctions: 0
# Generation time: 0.836 sec (0.546 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 0.86355 stdev: 0.14897
# Best fitness: 0.95793 - size: (8, 18) - species 5 - id 9499
# Average adjusted fitness: 0.416
# Mean genetic distance 2.375, standard deviation 0.423
# Population of 199 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   38     6      0.8    0.356     9
#      4    4    96      0.9    0.491     0
#      5    4    51      0.9    0.469     0
#      6    2    46      0.8    0.349     1
# Total extinctions: 0
# Generation time: 0.826 sec (0.583 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 0.86376 stdev: 0.14472
# Best fitness: 0.96214 - size: (9, 25) - species 4 - id 9736
# Average adjusted fitness: 0.419
# Mean genetic distance 2.373, standard deviation 0.459
# Population of 200 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   39    19      0.7    0.334    10
#      4    5    99      0.9    0.465     1
#      5    5    41      0.9    0.450     1
#      6    3    41      0.8    0.428     2
# Total extinctions: 0
# Generation time: 0.829 sec (0.616 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 0.85791 stdev: 0.14956
# Best fitness: 0.96214 - size: (4, 14) - species 4 - id 9936
# Average adjusted fitness: 0.404
# Mean genetic distance 2.427, standard deviation 0.462
# Population of 200 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   40    29      0.7    0.313    11
#      4    6    77      0.9    0.442     2
#      5    6    48      0.9    0.441     0
#      6    4    46      0.9    0.420     0
# Total extinctions: 0
# Generation time: 0.755 sec (0.643 average)
# Best genome: Key: 9736
# Fitness: 0.9621394230769231
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.4835402940618566, response=1.2994301834015503, activation=sigmoid, aggregation=sum)
# 	441 DefaultNodeGene(key=441, bias=-0.6758310580269128, response=2.344422759438652, activation=sigmoid, aggregation=sum)
# 	669 DefaultNodeGene(key=669, bias=3.565078549115034, response=0.23205955882031637, activation=sigmoid, aggregation=sum)
# 	1055 DefaultNodeGene(key=1055, bias=1.4561077782016258, response=0.9287498071050753, activation=sigmoid, aggregation=sum)
# 	1259 DefaultNodeGene(key=1259, bias=-4.290476623179171, response=0.0, activation=sigmoid, aggregation=sum)
# 	1319 DefaultNodeGene(key=1319, bias=-3.252477546706219, response=1.7763735939065488, activation=sigmoid, aggregation=sum)
# 	1660 DefaultNodeGene(key=1660, bias=0.6071144325741009, response=2.082000300044668, activation=sigmoid, aggregation=sum)
# 	1716 DefaultNodeGene(key=1716, bias=-0.5618044662219512, response=0.5958759468755173, activation=sigmoid, aggregation=sum)
# 	1868 DefaultNodeGene(key=1868, bias=0.1357634856324972, response=0.881691579302391, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-19, 0), weight=2.2090134753095017, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1055), weight=1.011006108471038, enabled=True)
# 	DefaultConnectionGene(key=(-17, 669), weight=0.0, enabled=True)
# 	DefaultConnectionGene(key=(-17, 1716), weight=0.6848724729520268, enabled=True)
# 	DefaultConnectionGene(key=(-15, 1259), weight=1.1582079493417246, enabled=True)
# 	DefaultConnectionGene(key=(-14, 441), weight=1.5729547240456516, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1259), weight=1.335995856837283, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=0.4902918804977308, enabled=False)
# 	DefaultConnectionGene(key=(-13, 1319), weight=0.2454748840870689, enabled=True)
# 	DefaultConnectionGene(key=(-13, 1868), weight=0.7914551250558591, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1716), weight=0.6081274250102212, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=0.8074223820006753, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=7.521230065386969, enabled=True)
# 	DefaultConnectionGene(key=(-8, 441), weight=0.7778279102525859, enabled=True)
# 	DefaultConnectionGene(key=(-7, 441), weight=1.201135980278957, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=3.0777060318927085, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1055), weight=1.6469292970584373, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.2671862693506021, enabled=True)
# 	DefaultConnectionGene(key=(-4, 441), weight=0.2623496342483331, enabled=False)
# 	DefaultConnectionGene(key=(-4, 669), weight=0.6257287145258298, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.4325043096381578, enabled=False)
# 	DefaultConnectionGene(key=(-1, 441), weight=5.753544574278597, enabled=True)
# 	DefaultConnectionGene(key=(441, 0), weight=3.8524717169175853, enabled=True)
# 	DefaultConnectionGene(key=(669, 441), weight=0.34171825684192086, enabled=False)
# 	DefaultConnectionGene(key=(669, 1259), weight=0.5271098033762232, enabled=True)
# 	DefaultConnectionGene(key=(1259, 441), weight=0.0873632709602391, enabled=True)
# 	DefaultConnectionGene(key=(1319, 0), weight=0.5901820894800481, enabled=False)
# 	DefaultConnectionGene(key=(1319, 1660), weight=1.1909465846931222, enabled=True)
# 	DefaultConnectionGene(key=(1716, 669), weight=0.5101235313448631, enabled=True)
# 	DefaultConnectionGene(key=(1868, 1319), weight=0.19249861080670233, enabled=True)
# Final test ROC AUC: 0.8958
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80        14
#            1       0.73      0.92      0.81        12
#
#     accuracy                           0.81        26
#    macro avg       0.82      0.82      0.81        26
# weighted avg       0.83      0.81      0.81        26
#
#
# Confusion Matrix:
#
# [[10  4]
#  [ 1 11]]

# %%
    import matplotlib.pyplot as plt
    import seaborn as sns
    from sklearn.metrics import confusion_matrix, classification_report

    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Non-Autism", "Autism"], yticklabels=["Non-Autism", "Autism"])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()
